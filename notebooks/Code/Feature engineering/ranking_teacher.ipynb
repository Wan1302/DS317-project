# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# ## Load file

# %%
import pandas as pd
import json
import polars as pl

# %%
path = '/gdrive/MyDrive/Nhóm 1/2 Bài tập trên lớp/Thực hành Final/Data processed/teacher_translated.json'
df = pd.read_json(path, lines=True)
df.head()
# Out:
#     id name        name_en                                              about  \
# 0  T_1  刘燕妮      Yanni Liu  graduated from the philosophy department of pe...
# 1  T_2   陈怡        Yi Chen  born in chongqing in 1945, he graduated from h...
# 2  T_3   程钢     Gang Cheng  cheng gang is the course leader of "introducti...
# 3  T_4  谢维和     xie wei he  xie weihe, phd, professor, doctoral supervisor...
# 4  T_5  史静寰  Jing-huan Shi  shi jinghuan, female, professor and doctoral s...
#
#              job_title             org_name
# 0             lecturer  tsinghua university
# 1            professor  tsinghua university
# 2  associate professor  tsinghua university
# 3            professor  tsinghua university
# 4            professor  tsinghua university

# %%
df.shape
# Out:
# (9876, 6)

# %%
df['org_name'].value_counts()
# Out:
# org_name
# tsinghua university                                           678
# xi'an jiaotong university                                     375
# shandong university                                           173
# shaanxi industrial vocational and technical college           153
# beijing normal university                                     149
#                                                              ...
# fujian agriculture and forestry university jinshan college      1
# beijing arts and crafts advanced technical school               1
# beijing normal university school of continuing education        1
# rwth aachen university                                          1
# university of sydney                                            1
# Name: count, Length: 725, dtype: int64

# %% [markdown]
# ## Load file ranking of universities in github

# %%
df_ranking = pd.read_csv('uni_02.csv', encoding='utf-16')
df_ranking.head()
# Out:
#   rank                                   name  number_students  \
# 0    1                   University of Oxford            20664
# 1    2     California Institute of Technology             2240
# 2    3                University of Cambridge            18978
# 3    4                    Stanford University            16135
# 4    5  Massachusetts Institute of Technology            11247
#
#    student_staff_ratio  intl_students  female_male_ratio  overall_score  \
# 0                 11.2           41.0               46.0           95.4
# 1                  6.4           30.0               34.0           94.5
# 2                 10.9           37.0               47.0           94.4
# 3                  7.3           23.0               43.0           94.3
# 4                  8.6           34.0               39.0           93.6
#
#    teaching_score  research_score  citations_score  industry_income_score  \
# 0            90.5            99.6             98.4                   65.5
# 1            92.1            97.2             97.9                   88.0
# 2            91.4            98.7             95.8                   59.3
# 3            92.8            96.4             99.9                   66.2
# 4            90.5            92.4             99.5                   86.9
#
#    international_outlook_score  \
# 0                         96.4
# 1                         82.5
# 2                         95.0
# 3                         79.5
# 4                         89.0
#
#                                              address  \
# 0  University Offices, Wellington Square, Oxford,...
# 1  1200 East California Boulevard, Pasadena, Cali...
# 2  The Old Schools, Trinity Lane, Cambridge, Camb...
# 3  450 Serra Mall, Stanford, California, 94305–20...
# 4  77 Massachusetts Avenue, Cambridge, Massachuse...
#
#                          street_address locality_address  region_address  \
# 0  University Offices Wellington Square           Oxford     Oxfordshire
# 1        1200 East California Boulevard         Pasadena              CA
# 2          The Old Schools Trinity Lane        Cambridge  Cambridgeshire
# 3                        450 Serra Mall         Stanford              CA
# 4               77 Massachusetts Avenue        Cambridge              MA
#
#   postcode_address country_address
# 0          OX1 2JD  United Kingdom
# 1            91125   United States
# 2          CB2 1TN  United Kingdom
# 3       94305–2004   United States
# 4       02139-4307   United States

# %% [markdown]
# ## Merge two files based on name of universities

# %%
df['org_name_lower'] = df['org_name'].str.lower()
df_ranking['name_lower'] = df_ranking['name'].str.lower()

# Merge hai DataFrame
df = df.merge(df_ranking[['name_lower', 'rank']], left_on='org_name_lower', right_on='name_lower', how='left')

# Loại bỏ các cột không cần thiết
df.drop(columns=['org_name_lower', 'name_lower'], inplace=True)

df.head()
# Out:
#     id name        name_en                                              about  \
# 0  T_1  刘燕妮      Yanni Liu  graduated from the philosophy department of pe...
# 1  T_2   陈怡        Yi Chen  born in chongqing in 1945, he graduated from h...
# 2  T_3   程钢     Gang Cheng  cheng gang is the course leader of "introducti...
# 3  T_4  谢维和     xie wei he  xie weihe, phd, professor, doctoral supervisor...
# 4  T_5  史静寰  Jing-huan Shi  shi jinghuan, female, professor and doctoral s...
#
#              job_title             org_name rank
# 0             lecturer  tsinghua university   23
# 1            professor  tsinghua university   23
# 2  associate professor  tsinghua university   23
# 3            professor  tsinghua university   23
# 4            professor  tsinghua university   23

# %%
df.to_csv('teacher_rank.csv', index=False)

# %% [markdown]
# ## Drop the rows without rank

# %%
df.dropna(subset=['rank'], inplace=True)

# %%
df.shape
# Out:
# (2929, 7)

# %% [markdown]
# ## Load file course-teacher

# %%
course_teacher = pd.read_csv("course-teacher.txt", sep='\t', header=None, names=['course_id', 'id'])
course_teacher.head()
# Out:
#   course_id      id
# 0  C_323899  T_5092
# 1  C_323899  T_5092
# 2  C_324384  T_6164
# 3  C_324384  T_6472
# 4  C_324384  T_6471

# %% [markdown]
# ## Merge two files based on id

# %%
joined_df = pd.merge(df, course_teacher, left_on='id', right_on='id', how='inner')
joined_df.head()
# Out:
#     id name    name_en                                              about  \
# 0  T_1  刘燕妮  Yanni Liu  graduated from the philosophy department of pe...
# 1  T_1  刘燕妮  Yanni Liu  graduated from the philosophy department of pe...
# 2  T_1  刘燕妮  Yanni Liu  graduated from the philosophy department of pe...
# 3  T_1  刘燕妮  Yanni Liu  graduated from the philosophy department of pe...
# 4  T_1  刘燕妮  Yanni Liu  graduated from the philosophy department of pe...
#
#   job_title             org_name rank course_id
# 0  lecturer  tsinghua university   23  C_375629
# 1  lecturer  tsinghua university   23  C_425434
# 2  lecturer  tsinghua university   23  C_445639
# 3  lecturer  tsinghua university   23  C_445639
# 4  lecturer  tsinghua university   23  C_676649

# %%
joined_df.drop(columns=['id', 'name', 'name_en', 'about', 'job_title', 'org_name'], inplace=True)
joined_df.head()
# Out:
#   rank course_id
# 0   23  C_375629
# 1   23  C_425434
# 2   23  C_445639
# 3   23  C_445639
# 4   23  C_676649

# %%
cols = list(joined_df.columns)
idx_course_id = cols.index('course_id')
idx_rank = cols.index('rank')
cols[idx_course_id], cols[idx_rank] = cols[idx_rank], cols[idx_course_id]
joined_df = joined_df[cols]

joined_df.head()
# Out:
#   course_id rank
# 0  C_375629   23
# 1  C_425434   23
# 2  C_445639   23
# 3  C_445639   23
# 4  C_676649   23

# %% [markdown]
# ## Save the file

# %%
joined_df.to_csv('course_teacher_rank.csv', index=False)
