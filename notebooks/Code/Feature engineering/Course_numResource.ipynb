# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import polars as pl
from tqdm import tqdm
import os
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy

# %%
path = '/gdrive/MyDrive/Nhóm 1/2 Bài tập trên lớp/Bài tập thực hành 1/Translated_Data/course_translated.json'

course_df = pl.read_json(path)
course_df = course_df.to_pandas()
course_df.head()
# Out:
#          id                                               name  \
# 0  C_584313                 introduction to "zi zhi tong jian"
# 1  C_584329  calculus - limit theory and functions of one v...
# 2  C_584381                                    photojournalism
# 3  C_597208                 data mining: theory and algorithms
# 4  C_597225                                university computer
#
#                                                field prerequisites  \
# 0     ['history', 'chinese language and literature']
# 1  ['applied economics', 'mathematics', 'physics'...
# 2                              ['art', 'journalism']
# 3                ['computer science and technology']
# 4                                                 []
#
#                                                about  \
# 0  through the teacher's guidance, students can g...
# 1  this course is a basic mathematics course in s...
# 2  master basic photography skills, understand ho...
# 3  the most interesting theory + the most useful ...
# 4  university computer courses will be guided by ...
#
#                                             resource
# 0  [{'titles': ['第一课 导论与三家分晋', '导论', '导论'], 'reso...
# 1  [{'titles': ['序言', '序言', '序言'], 'resource_id':...
# 2  [{'titles': ['第一章 绪论', '第一讲 引言1', '引言1'], 'res...
# 3  [{'titles': ['走进数据科学：博大精深，美不胜收', '整装待发', 'Vide...
# 4  [{'titles': ['第1周： 基于计算机的问题求解', '课程介绍', '开篇'],...

# %%
def count_element(x):
    return len(x)

course_df['number of resources'] = course_df['resource'].apply(count_element)
course_df[['id', 'name', 'number of resources']]
# Out:
#              id                                               name  \
# 0      C_584313                 introduction to "zi zhi tong jian"
# 1      C_584329  calculus - limit theory and functions of one v...
# 2      C_584381                                    photojournalism
# 3      C_597208                 data mining: theory and algorithms
# 4      C_597225                                university computer
# ...         ...                                                ...
# 3776  C_2338076                (wind project) software engineering
# 3777  C_2341259   (wind project) object-oriented programming (c++)
# 3778  C_2337996             (wind project) data structure (part 2)
# 3779  C_1945689                          machine learning bootcamp
# 3780  C_2329163                 creative writing practice tutorial
#
#       number of resources
# 0                      91
# 1                     170
# 2                     127
# 3                     125
# 4                     165
# ...                   ...
# 3776                  103
# 3777                   76
# 3778                  324
# 3779                   76
# 3780                  101
#
# [3781 rows x 3 columns]

# %%
path = '/gdrive/MyDrive/Nhóm 1/2 Bài tập trên lớp/Bài tập thực hành 1/Translated_Data'
course_df[['id', 'number of resources']].to_csv(os.path.join(path, 'course_num_resources.csv'), index=False)
